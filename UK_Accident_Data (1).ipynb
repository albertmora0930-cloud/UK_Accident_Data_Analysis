# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import warnings

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
warnings.filterwarnings('ignore')

# %%
road = pd.read_csv('uk_road_accident.csv')

# %%
road
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious      5/6/2019  51.506187
# 1       200701BS65737           Serious      2/7/2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight      3/9/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %%
road.describe().round()
# Out:
#        Latitude  Longitude  Number_of_Casualties  Number_of_Vehicles
# count  660654.0   660653.0              660679.0            660679.0
# mean       53.0       -1.0                   1.0                 2.0
# std         1.0        1.0                   1.0                 1.0
# min        50.0       -8.0                   1.0                 1.0
# 25%        51.0       -2.0                   1.0                 1.0
# 50%        52.0       -1.0                   1.0                 2.0
# 75%        53.0       -0.0                   1.0                 2.0
# max        61.0        2.0                  68.0                32.0

# %%
road.describe().T
# Out:
#                          count       mean       std        min        25%  \
# Latitude              660654.0  52.553866  1.406922  49.914430  51.490690
# Longitude             660653.0  -1.431210  1.383330  -7.516225  -2.332291
# Number_of_Casualties  660679.0   1.357040  0.824847   1.000000   1.000000
# Number_of_Vehicles    660679.0   1.831255  0.715269   1.000000   1.000000
#
#                             50%        75%        max
# Latitude              52.315641  53.453452  60.757544
# Longitude             -1.411667  -0.232869   1.762010
# Number_of_Casualties   1.000000   1.000000  68.000000
# Number_of_Vehicles     2.000000   2.000000  32.000000

# %%
road['Accident_Severity']
# Out:
# 0         Serious
# 1         Serious
# 2         Serious
# 3         Serious
# 4          Slight
#            ...
# 660674     Slight
# 660675     Slight
# 660676     Slight
# 660677    Serious
# 660678    Serious
# Name: Accident_Severity, Length: 660679, dtype: object

# %%
road['Accident Date']
# Out:
# 0           5/6/2019
# 1           2/7/2019
# 2         26-08-2019
# 3         16-08-2019
# 4           3/9/2019
#              ...
# 660674    18-02-2022
# 660675    21-02-2022
# 660676    23-02-2022
# 660677    23-02-2022
# 660678    28-02-2022
# Name: Accident Date, Length: 660679, dtype: object

# %%
road['Latitude']
# Out:
# 0         51.506187
# 1         51.495029
# 2         51.517715
# 3         51.495478
# 4         51.488576
#             ...
# 660674    57.374005
# 660675    57.232273
# 660676    57.585044
# 660677    57.214898
# 660678    57.575210
# Name: Latitude, Length: 660679, dtype: float64

# %%
road['Light_Conditions']
# Out:
# 0               Darkness - lights lit
# 1                            Daylight
# 2         Darkness - lighting unknown
# 3                            Daylight
# 4               Darkness - lights lit
#                      ...
# 660674                       Daylight
# 660675         Darkness - no lighting
# 660676                       Daylight
# 660677         Darkness - no lighting
# 660678                       Daylight
# Name: Light_Conditions, Length: 660679, dtype: object

# %%
road['District Area']
# Out:
# 0         Kensington and Chelsea
# 1         Kensington and Chelsea
# 2         Kensington and Chelsea
# 3         Kensington and Chelsea
# 4         Kensington and Chelsea
#                    ...
# 660674                  Highland
# 660675                  Highland
# 660676                  Highland
# 660677                  Highland
# 660678                  Highland
# Name: District Area, Length: 660679, dtype: object

# %%
road['Longitude']
# Out:
# 0        -0.209082
# 1        -0.173647
# 2        -0.210215
# 3        -0.202731
# 4        -0.192487
#             ...
# 660674   -3.467828
# 660675   -3.809281
# 660676   -3.862727
# 660677   -3.823997
# 660678   -3.895673
# Name: Longitude, Length: 660679, dtype: float64

# %%
road['Number_of_Casualties']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 660674    2
# 660675    1
# 660676    1
# 660677    1
# 660678    1
# Name: Number_of_Casualties, Length: 660679, dtype: int64

# %%
road['Number_of_Vehicles']
# Out:
# 0         2
# 1         2
# 2         3
# 3         4
# 4         2
#          ..
# 660674    1
# 660675    1
# 660676    3
# 660677    2
# 660678    1
# Name: Number_of_Vehicles, Length: 660679, dtype: int64

# %%
road['Road_Surface_Conditions']
# Out:
# 0                  Dry
# 1          Wet or damp
# 2                  Dry
# 3                  Dry
# 4                  Dry
#               ...
# 660674             Dry
# 660675    Frost or ice
# 660676    Frost or ice
# 660677     Wet or damp
# 660678     Wet or damp
# Name: Road_Surface_Conditions, Length: 660679, dtype: object

# %%
road['Road_Type']
# Out:
# 0         Single carriageway
# 1         Single carriageway
# 2                        NaN
# 3         Single carriageway
# 4                        NaN
#                  ...
# 660674    Single carriageway
# 660675    Single carriageway
# 660676    Single carriageway
# 660677    Single carriageway
# 660678      Dual carriageway
# Name: Road_Type, Length: 660679, dtype: object

# %%
road['Urban_or_Rural_Area']
# Out:
# 0         Urban
# 1         Urban
# 2         Urban
# 3         Urban
# 4         Urban
#           ...
# 660674    Rural
# 660675    Rural
# 660676    Rural
# 660677    Rural
# 660678    Rural
# Name: Urban_or_Rural_Area, Length: 660679, dtype: object

# %%
road['Weather_Conditions']
# Out:
# 0            Fine no high winds
# 1         Raining no high winds
# 2                           NaN
# 3            Fine no high winds
# 4                           NaN
#                   ...
# 660674       Fine no high winds
# 660675       Fine no high winds
# 660676       Fine no high winds
# 660677       Fine no high winds
# 660678    Snowing no high winds
# Name: Weather_Conditions, Length: 660679, dtype: object

# %%
road['Vehicle_Type']
# Out:
# 0                                          Car
# 1                                          Car
# 2                        Taxi/Private hire car
# 3         Bus or coach (17 or more pass seats)
# 4                                Other vehicle
#                           ...
# 660674                                     Car
# 660675                                     Car
# 660676                                     Car
# 660677                   Motorcycle over 500cc
# 660678                                     Car
# Name: Vehicle_Type, Length: 660679, dtype: object

# %%
road.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %%
road['Latitude'] = road['Latitude'].fillna(road['Latitude'].mode()[0])

# %%
road['Longitude'] = road['Longitude'].fillna(road['Longitude'].mode()[0])

# %%
road['Road_Surface_Conditions'] = road['Road_Surface_Conditions'].fillna('unaccounted')

# %%
road['Road_Type'] = road['Road_Type'].fillna('unaccounted')

# %%
road['Urban_or_Rural_Area'] = road['Urban_or_Rural_Area'].fillna(road['Urban_or_Rural_Area'].mode()[0])

# %%
road['Weather_Conditions'] = road['Weather_Conditions'].fillna('unaccounted')

# %%
road.isnull().sum()
# Out:
# Index                      0
# Accident_Severity          0
# Accident Date              0
# Latitude                   0
# Light_Conditions           0
# District Area              0
# Longitude                  0
# Number_of_Casualties       0
# Number_of_Vehicles         0
# Road_Surface_Conditions    0
# Road_Type                  0
# Urban_or_Rural_Area        0
# Weather_Conditions         0
# Vehicle_Type               0
# dtype: int64

# %%
road['Accident_Severity'] = road['Accident_Severity'].astype('object')
road['Accident Date'] = road['Accident Date'].astype('object')
road['Light_Conditions'] = road['Light_Conditions'].astype('object')
road['District Area'] = road['District Area'].astype('object')
road['Road_Surface_Conditions'] = road['Road_Surface_Conditions'].astype('object')
road['Road_Type'] = road['Road_Type'].astype('object')
road['Urban_or_Rural_Area'] = road['Urban_or_Rural_Area'].astype('object')
road['Weather_Conditions'] = road['Weather_Conditions'].astype('object')
road['Vehicle_Type'] = road['Vehicle_Type'].astype('object')

# %%
road.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660679 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660679 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  660679 non-null  object
#  10  Road_Type                660679 non-null  object
#  11  Urban_or_Rural_Area      660679 non-null  object
#  12  Weather_Conditions       660679 non-null  object
# ...

# %% [markdown]
# <h2>Clearing any Inconsistences with the Data set</h2>

# %%
road['Accident Date'] = road['Accident Date'].str.strip() #to remove any extra white space
road['Accident Date'] = road['Accident Date'].astype('str') #to convert into a string 
road['Accident Date'] = road['Accident Date'].str.replace('/','-')

# %%
road['Accident Date'] = pd.to_datetime(road['Accident Date'], dayfirst = True, errors = 'coerce')

# %% [markdown]
# <h2>Adjusting Data types</h2>

# %%
road.dtypes
# Out:
# Index                              object
# Accident_Severity                  object
# Accident Date              datetime64[ns]
# Latitude                          float64
# Light_Conditions                   object
# District Area                      object
# Longitude                         float64
# Number_of_Casualties                int64
# Number_of_Vehicles                  int64
# Road_Surface_Conditions            object
# Road_Type                          object
# Urban_or_Rural_Area                object
# Weather_Conditions                 object
# Vehicle_Type                       object
# dtype: object

# %%
road['Year'] = road['Accident Date'].dt.year
road['Month'] = road['Accident Date'].dt.month
road['Day'] = road['Accident Date'].dt.day
road['DayofWeek'] = road['Accident Date'].dt.dayofweek
road['Hour'] = road['Accident Date'].dt.hour

# %%
road['Accident Date'] = road['Accident Date'].fillna('unaccounted')
road['Year'] = road['Year'].fillna('unaccounted')
road['Month'] = road['Month'].fillna('unaccounted')
road['Day'] = road['Day'].fillna('unaccounted')
road['DayofWeek'] = road['DayofWeek'].fillna('unaccounted')
road['Hour'] = road['Hour'].fillna('unaccounted')
road.isnull().sum()
# Out:
# Index                      0
# Accident_Severity          0
# Accident Date              0
# Latitude                   0
# Light_Conditions           0
# District Area              0
# Longitude                  0
# Number_of_Casualties       0
# Number_of_Vehicles         0
# Road_Surface_Conditions    0
# Road_Type                  0
# Urban_or_Rural_Area        0
# Weather_Conditions         0
# Vehicle_Type               0
# Year                       0
# Month                      0
# Day                        0
# DayofWeek                  0
# Hour                       0
# dtype: int64

# %% [markdown]
# <h2>25 Question with descriptive analysis </h2>

# %% [markdown]
# A1. In what year have the most accident?

# %%
pd.crosstab(road['Vehicle_Type'],road['Year']).round().idxmax
# Out:
# <bound method DataFrame.idxmax of Year                                     2019    2020    2021    2022
# Vehicle_Type
# Agricultural vehicle                      636     562     450     299
# Bus or coach (17 or more pass seats)    10483    6709    4155    4531
# Car                                    130304  127894  128026  111768
# Data missing or out of range                0       6       0       0
# Goods 7.5 tonnes mgw and over            6247    4528    3569    2963
# Goods over 3.5t. and under 7.5t          2049    1545    1395    1107
# Minibus (8 - 16 passenger seats)          625     530     420     401
# Motorcycle 125cc and under               4313    4104    3273    3579
# Motorcycle 50cc and under                2136    1764    1968    1735
# Motorcycle over 125cc and up to 500cc    2446    1925    1915    1370
# Motorcycle over 500cc                    7686    6745    6110    5116
# Other vehicle                            1588    1533    1420    1096
# ...

# %% [markdown]
# 1. How many accident happen base on the data?

# %%
number_accident = len(road)
print(number_accident)
# Out:
# 660679

# %% [markdown]
# Analysis : There are 660679 accident base on the data

# %% [markdown]
# 2. What is the distribution of accident severities by vehicle type?

# %%
pd.crosstab(road['Vehicle_Type'], road['Accident_Severity'])
# Out:
# Accident_Severity                      Fatal  Serious  Slight
# Vehicle_Type
# Agricultural vehicle                      21      282    1644
# Bus or coach (17 or more pass seats)     325     3373   22180
# Car                                     6577    66461  424954
# Data missing or out of range               0        0       6
# Goods 7.5 tonnes mgw and over            216     2321   14770
# Goods over 3.5t. and under 7.5t           67      857    5172
# Minibus (8 - 16 passenger seats)          29      276    1671
# Motorcycle 125cc and under               189     2031   13049
# Motorcycle 50cc and under                 95     1014    6494
# Motorcycle over 125cc and up to 500cc    105     1014    6537
# Motorcycle over 500cc                    339     3457   21861
# Other vehicle                             70      767    4800
# Pedal cycle                                6       39     152
# Ridden horse                               0        0       4
# ...

# %% [markdown]
# Analysis:
#  This shows how different types of vehicles are associated with different severity levels.

# %% [markdown]
# 3.What is the correlation matrix for numerical accident features?

# %%
road[['Number_of_Casualties','Number_of_Vehicles']].corr().round()
# Out:
#                       Number_of_Casualties  Number_of_Vehicles
# Number_of_Casualties                   1.0                 0.0
# Number_of_Vehicles                     0.0                 1.0

# %% [markdown]
# Analysis: This shows correlation between casualties and vehicles in accidents.

# %% [markdown]
# 4. How many accidents involved more than 2 vehicles?

# %%
len(road[road['Number_of_Vehicles'] > 2])
# Out:
# 67897

# %% [markdown]
# Analysis:
# This gives the count of multi-vehicle accidents.

# %% [markdown]
# 5.How does accident severity vary by road surface condition?

# %%
pd.crosstab(road['Road_Surface_Conditions'], road['Accident_Severity'])
# Out:
# Accident_Severity        Fatal  Serious  Slight
# Road_Surface_Conditions
# Dry                       5788    61638  380395
# Flood over 3cm. deep        23      152     842
# Frost or ice               193     2007   16317
# Snow                        35      565    5290
# Wet or damp               2620    23785  160303
# unaccounted                  2       70     654

# %% [markdown]
# Analysis: This shows how road surface conditions impact accident severity.

# %% [markdown]
# 6. What is the distribution of accident severities?

# %%
road['Accident_Severity'].value_counts()
# Out:
# Accident_Severity
# Slight     563801
# Serious     88217
# Fatal        8661
# Name: count, dtype: int64

# %% [markdown]
# Analysis: This provides the distribution of accident severity levels (Slight, Serious, Fatal).

# %% [markdown]
# 7. What is the average number of casualties per accident?

# %%
road['Number_of_Casualties'].mean().round()
# Out:
# np.float64(1.0)

# %% [markdown]
# Analysis: This shows the average casualties per accident across the dataset.

# %% [markdown]
# 8. What is the maximum number of casualties in a single accident?

# %%
road['Number_of_Casualties'].max()
# Out:
# np.int64(68)

# %% [markdown]
# Analysis: This indicates the worst-case accident in terms of casualties.

# %% [markdown]
# 9. What is the average number of vehicles per accident?

# %%
road['Number_of_Vehicles'].mean().round()
# Out:
# np.float64(2.0)

# %% [markdown]
# Analysis: This gives an idea of how many vehicles are typically involved in an accident.

# %% [markdown]
# 10. What is the most common road surface condition during accidents?

# %%
road['Road_Surface_Conditions'].value_counts().idxmax()
# Out:
# 'Dry'

# %% [markdown]
# Analysis: This shows which road surface condition occurs most frequently during accidents.

# %% [markdown]
# 11. What is the distribution of accidents by road type?

# %%
road['Road_Type'].value_counts()
# Out:
# Road_Type
# Single carriageway    492143
# Dual carriageway       99424
# Roundabout             43992
# One way street         13559
# Slip road               7041
# unaccounted             4520
# Name: count, dtype: int64

# %% [markdown]
# Analysis: This provides insight into which road types experience more accidents.

# %% [markdown]
# 12. How many accidents occurred in urban vs rural areas?

# %%
road['Urban_or_Rural_Area'].value_counts()
# Out:
# Urban_or_Rural_Area
# Urban          421678
# Rural          238990
# Unallocated        11
# Name: count, dtype: int64

# %% [markdown]
# Analysis: This helps compare accident counts in urban vs rural areas.

# %% [markdown]
# 13.What is the most common weather condition during accidents?

# %%
road['Weather_Conditions'].value_counts().idxmax()
# Out:
# 'Fine no high winds'

# %% [markdown]
# Analysis: This identifies the most frequent weather condition during accidents.

# %% [markdown]
# 14. What is the distribution of accidents by light conditions?

# %%
road['Light_Conditions'].value_counts()
# Out:
# Light_Conditions
# Daylight                       484880
# Darkness - lights lit          129335
# Darkness - no lighting          37437
# Darkness - lighting unknown      6484
# Darkness - lights unlit          2543
# Name: count, dtype: int64

# %% [markdown]
# Analysis: This shows how light conditions (daylight, darkness) affect accident frequency.

# %% [markdown]
# 15. What is the most common vehicle type involved in accidents?

# %%
road['Vehicle_Type'].value_counts().idxmax()
# Out:
# 'Car'

# %% [markdown]
# Analysis: This shows which type of vehicle is most commonly involved in accidents.

# %% [markdown]
# 16. How many accidents occurred each year?

# %%
pd.to_datetime(road['Accident Date'], errors='coerce').dt.year.value_counts().sort_index()
# Out:
# Accident Date
# 2019    182115
# 2020    170591
# 2021    163554
# 2022    144419
# Name: count, dtype: int64

# %% [markdown]
# Analysis: This shows accident trends over different years.

# %% [markdown]
# 17. What is the correlation between number of vehicles and casualties?

# %%
road[['Number_of_Vehicles','Number_of_Casualties']].corr()
# Out:
#                       Number_of_Vehicles  Number_of_Casualties
# Number_of_Vehicles              1.000000              0.228889
# Number_of_Casualties            0.228889              1.000000

# %% [markdown]
# Analysis: This checks if more vehicles involved lead to higher casualties.

# %% [markdown]
# 18. Which district area has the highest number of accidents?

# %%
road['District Area'].value_counts().idxmax()
# Out:
# 'Birmingham'

# %% [markdown]
# Analysis: This identifies the district with the most accidents.

# %% [markdown]
# 19. Which district has the highest average casualties per accident?

# %%
road.groupby('District Area')['Number_of_Casualties'].mean().idxmax()
# Out:
# 'Blaeu Gwent'

# %% [markdown]
# Analysis: This identifies the district with the most severe accidents on average.

# %% [markdown]
# 20.  What is the proportion of accident severities?

# %%
road['Accident_Severity'].value_counts(normalize=True).round()
# Out:
# Accident_Severity
# Slight     1.0
# Serious    0.0
# Fatal      0.0
# Name: proportion, dtype: float64

# %% [markdown]
# Analysis: This shows the proportion of different accident severities.

# %% [markdown]
# What is the District have the most accident in year 2019

# %% [markdown]
# 21. What is the distribution of accident severitie?

# %%
sns.countplot(x='Accident_Severity', data=road, order=road['Accident_Severity'].value_counts().index)
plt.title("Distribution of Accident Severities")
plt.xlabel("Accident Severity")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Analysis: This shows the count of accidents by severity (Slight, Serious, Fatal).

# %% [markdown]
# 22. What is the distribution of accidents by light conditions?

# %%
sns.countplot(x='Light_Conditions', data=road, order=road['Light_Conditions'].value_counts().index)
plt.title("Accidents by Light Conditions")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Analysis: This reveals whether most accidents happen in daylight or in darkness.

# %% [markdown]
# 23. Which day of the week has the most accidents?

# %%
road['DayofWeek'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(6,6))
plt.title("Accidents by Day of Week")
plt.ylabel("")
plt.show()

# %% [markdown]
# Analysis: The pie chart reveals that weekdays, especially Friday, tend to have the highest number of accidents. This may be due to increased traffic volume as people commute to and from work.

# %% [markdown]
# 24. What type of vehicle is most commonly involved in accidents?

# %%
road['Vehicle_Type'].value_counts().head(6).plot(kind='barh', color='orange', figsize=(8,4))
plt.title("Top Vehicle Types Involved in Accidents")
plt.xlabel("Number of Accidents")
plt.ylabel("Vehicle Type")
plt.show()

# %% [markdown]
# 25. Which coordinates are the most accident-prone?

# %%
road.groupby(['Latitude','Longitude']).size().reset_index(name='Accident_Count').nlargest(100, 'Accident_Count').plot(
    kind='scatter', x='Longitude', y='Latitude', c='Accident_Count', cmap='BrBG', figsize=(8,6), alpha=0.6)
plt.title("Top 100 Accident-Prone Locations")
plt.show()

# %% [markdown]
# Analysis: The scatter plot highlights accident hotspots by mapping the top accident-prone coordinates. A few clusters stand out, showing where road design, traffic flow, or other conditions may increase risks.

# %% [markdown]
# 26.

# %%
london_df = road[road['District Area']== 'City of London']

# %%
london_fatal = london_df[london_df['Accident_Severity'] == 'Fatal']

# %%
import folium
from folium.plugins import HeatMap

locations  = list(zip(london_fatal['Latitude'],london_fatal['Longitude']))

m = folium.Map(location=[london_fatal['Latitude'].mean(), london_fatal['Longitude'].mean()], zoom_start=10)
heat = road[['Latitude','Longitude']].dropna().sample(1000).values.tolist()
HeatMap(heat, radius=7,blur=4).add_to(m)
/# Step 3: Add the heatmap layer
HeatMap(locations).add_to(m)

# Step 4: Save or dspilay the map
m.save('accident_heatmap.html')  # Save the map as an HTML file
m  # Display the map in a Jupyter
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
# Scatterplot of casualties vs vehicles
sns.scatterplot(x='Number_of_Vehicles', y='Number_of_Casualties', data=road, alpha=0.5)
plt.title("Casualties vs Vehicles Involved")
plt.show()

# %%
# Pie chart of accidents by light conditions
road['Light_Conditions'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(6,6))
plt.title("Accidents by Light Conditions")
plt.ylabel("")
plt.show()

# %% [markdown]
# Insight: Most accidents happen in busy areas and on main roads. They often involve several vehicles and can occur both in the day and at night. This shows that traffic density and visibility are big factors in road accidents.

# %% [markdown]
# 27. Selecting 6 to 7 district amongst the district area and apply specific analysis

# %%
# 7 districts
district_data =  ['Birmingham', 'Leeds', 'Manchester', 'Liverpool', 'Sheffield', 'Bristol', 'Nottingham']

road_district = road[road['District Area'].isin(district_data)]

# %% [markdown]
# <h1>Compare Accident Severity (District vs Overall)</h1>

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Accident_Severity', data=road, order=road['Accident_Severity'].value_counts().index, color='gray', alpha=0.5, label='Overall')
sns.countplot(x='Accident_Severity', data=road_district, order=road['Accident_Severity'].value_counts().index, color='red', alpha=0.6, label='Selected Districts')
plt.title("Accident Severity: Selected Districts vs Overall")
plt.legend()
plt.show()

# %% [markdown]
# <h1>Compare Casualties per Accident in Districts</h1>

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='District Area', y='Number_of_Casualties', data=road_district)
plt.title("Casualties per Accident in Selected Districts")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h1>Compare Accident Counst by Districts</h1>

# %%
road_district['District Area'].value_counts().plot(kind='bar', figsize=(8,5), color='skyblue')
plt.title("Number of Accidents per Selected District")
plt.ylabel("Accident Count")
plt.show()

# %% [markdown]
# <h1>Comapare Weather Conditions in Selected Districts</h1>

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Weather_Conditions', data=road_district, order=road['Weather_Conditions'].value_counts().index)
plt.title("Weather Conditions in Selected Districts")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h1>Compare Accidents by Time of Day</h1>

# %%
plt.figure(figsize=(10,6))
sns.histplot(road['Hour'], bins=24, color='gray', label='Overall', alpha=0.4)
sns.histplot(road_district['Hour'], bins=24, color='red', label='Selected Districts', alpha=0.6)
plt.title("Accidents by Hour: Selected Districts vs Overall")
plt.xlabel("Hour of Day")
plt.ylabel("Accident Count")
plt.legend()
plt.show()

# %% [markdown]
# Insight: Mosth accidents happen in daylight and involve cars, but serious crashes with more casualties often accur at night in bad weather, or on busy urban roads.

# %% [markdown]
# 28.In what district areas have the most number or have the highest number of accidents?

# %%
most_district = road['District Area'].value_counts().head(10).index
plt.figure(figsize=(10,6))
sns.countplot(data=road[road['District Area'].isin(most_district)],
             x='District Area',
             order=most_district,
             palette='viridis')
plt.title("Top 10 District Areas with Most Accidents")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Insight: A few districts have far more accidents that others

# %% [markdown]
# 29. How does accident severity vary across different light conditions?

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=road, 
              x='Light_Conditions', 
              hue='Accident_Severity', 
              palette='magma')
plt.title("Accident Severity under Different Light Conditions")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Insight: Most accidents happen in daylight, but severe crashes are more common at night, especially under poor lighting.

# %% [markdown]
# 30. What is the relationship between the number of vehicles and casualties in an accident?

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=road, 
                x='Number_of_Vehicles', 
                y='Number_of_Casualties', 
                hue='Accident_Severity', 
                palette='coolwarm')
plt.title("Vehicles vs Casualties by Accident Severity")
plt.show()

# %% [markdown]
# Imsight: As the number of vehicles increases, the number of casualties also tends to rise, showing that multi-vehicle crashes are usually more dangerous.

# %% [markdown]
# 31.How do casualties differ by road surface conditions?

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=road, 
            x='Road_Surface_Conditions', 
            y='Number_of_Casualties', 
            palette='Set2')
plt.title("Casualties by Road Surface Conditions")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Insight:
# Accidents on wet or icy roads often lead to higher casualties compared to dry conditions, highlighting the impact of weather on road safety.
